# %%
# !pip install roboflow
# Out:
# Collecting roboflow
#   Downloading roboflow-1.4.2-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: certifi in /home/sureshsecond/venv/lib/python3.10/site-packages (from roboflow) (2025.8.3)
# Requirement already satisfied: idna>=3.7 in /home/sureshsecond/venv/lib/python3.10/site-packages (from roboflow) (3.10)
# Requirement already satisfied: cycler in /home/sureshsecond/venv/lib/python3.10/site-packages (from roboflow) (0.12.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/sureshsecond/venv/lib/python3.10/site-packages (from roboflow) (1.4.9)
# Requirement already satisfied: matplotlib in /home/sureshsecond/venv/lib/python3.10/site-packages (from roboflow) (3.10.6)
# Requirement already satisfied: numpy<2.4,>=1.18.5 in /home/sureshsecond/venv/lib/python3.10/site-packages (from roboflow) (2.2.6)
# Collecting opencv-python-headless>=4.10.0 (from roboflow)
#   Using cached opencv_python_headless-5.0.0.93-cp37-abi3-manylinux_2_28_x86_64.whl.metadata (19 kB)
# Requirement already satisfied: Pillow>=7.1.2 in /home/sureshsecond/venv/lib/python3.10/site-packages (from roboflow) (11.3.0)
# WARNING: Retrying (Retry(total=4, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='pypi.org', port=443): Read timed out. (read timeout=15)")': /simple/pi-heif/
# Collecting pi-heif<2 (from roboflow)
#   Downloading pi_heif-1.4.0-cp310-cp310-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (6.3 kB)
# Collecting pillow-avif-plugin<2 (from roboflow)
#   Downloading pillow_avif_plugin-1.6.0-cp310-cp310-manylinux_2_28_x86_64.whl.metadata (2.2 kB)
# Requirement already satisfied: python-dateutil in /home/sureshsecond/venv/lib/python3.10/site-packages (from roboflow) (2.9.0.post0)
# Collecting python-dotenv (from roboflow)
#   Downloading python_dotenv-1.2.3-py3-none-any.whl.metadata (29 kB)
# Requirement already satisfied: requests in /home/sureshsecond/venv/lib/python3.10/site-packages (from roboflow) (2.32.5)
# Requirement already satisfied: six in /home/sureshsecond/venv/lib/python3.10/site-packages (from roboflow) (1.17.0)
# Requirement already satisfied: urllib3>=1.26.6 in /home/sureshsecond/venv/lib/python3.10/site-packages (from roboflow) (1.26.20)
# Requirement already satisfied: tqdm>=4.41.0 in /home/sureshsecond/venv/lib/python3.10/site-packages (from roboflow) (4.67.3)
# Requirement already satisfied: PyYAML>=5.3.1 in /home/sureshsecond/venv/lib/python3.10/site-packages (from roboflow) (6.0.2)
# Collecting requests_toolbelt (from roboflow)
#   Downloading requests_toolbelt-1.0.0-py2.py3-none-any.whl.metadata (14 kB)
# Collecting filetype (from roboflow)
#   Downloading filetype-1.2.0-py2.py3-none-any.whl.metadata (6.5 kB)
# Collecting typer<0.26,>=0.12.0 (from roboflow)
#   Downloading typer-0.25.1-py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: click>=8.0 in /home/sureshsecond/venv/lib/python3.10/site-packages (from roboflow) (8.2.1)
# Collecting shellingham>=1.3.0 (from typer<0.26,>=0.12.0->roboflow)
#   Downloading shellingham-1.5.4-py2.py3-none-any.whl.metadata (3.5 kB)
# Requirement already satisfied: rich>=13.8.0 in /home/sureshsecond/venv/lib/python3.10/site-packages (from typer<0.26,>=0.12.0->roboflow) (14.1.0)
# Collecting annotated-doc>=0.0.2 (from typer<0.26,>=0.12.0->roboflow)
#   Downloading annotated_doc-0.0.5-py3-none-any.whl.metadata (6.5 kB)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /home/sureshsecond/venv/lib/python3.10/site-packages (from rich>=13.8.0->typer<0.26,>=0.12.0->roboflow) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /home/sureshsecond/venv/lib/python3.10/site-packages (from rich>=13.8.0->typer<0.26,>=0.12.0->roboflow) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in /home/sureshsecond/venv/lib/python3.10/site-packages (from markdown-it-py>=2.2.0->rich>=13.8.0->typer<0.26,>=0.12.0->roboflow) (0.1.2)
# Requirement already satisfied: contourpy>=1.0.1 in /home/sureshsecond/venv/lib/python3.10/site-packages (from matplotlib->roboflow) (1.3.2)
# Requirement already satisfied: fonttools>=4.22.0 in /home/sureshsecond/venv/lib/python3.10/site-packages (from matplotlib->roboflow) (4.59.2)
# Requirement already satisfied: packaging>=20.0 in /home/sureshsecond/venv/lib/python3.10/site-packages (from matplotlib->roboflow) (25.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/sureshsecond/venv/lib/python3.10/site-packages (from matplotlib->roboflow) (3.2.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in /home/sureshsecond/venv/lib/python3.10/site-packages (from requests->roboflow) (3.4.3)
# Downloading roboflow-1.4.2-py3-none-any.whl (302 kB)
# Downloading pi_heif-1.4.0-cp310-cp310-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (1.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 5.1 MB/s  0:00:00 eta 0:00:01
# Downloading pillow_avif_plugin-1.6.0-cp310-cp310-manylinux_2_28_x86_64.whl (5.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.4/5.4 MB 5.6 MB/s  0:00:00 eta 0:00:01
# Downloading typer-0.25.1-py3-none-any.whl (58 kB)
# Downloading annotated_doc-0.0.5-py3-none-any.whl (5.3 kB)
# Using cached opencv_python_headless-5.0.0.93-cp37-abi3-manylinux_2_28_x86_64.whl (61.2 MB)
# Downloading shellingham-1.5.4-py2.py3-none-any.whl (9.8 kB)
# Downloading filetype-1.2.0-py2.py3-none-any.whl (19 kB)
# Downloading python_dotenv-1.2.3-py3-none-any.whl (22 kB)
# Downloading requests_toolbelt-1.0.0-py2.py3-none-any.whl (54 kB)
# Installing collected packages: pillow-avif-plugin, filetype, shellingham, python-dotenv, pi-heif, opencv-python-headless, annotated-doc, requests_toolbelt, typer, roboflow
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10/10 [roboflow]/10 [roboflow]toolbelt]less]
# Successfully installed annotated-doc-0.0.5 filetype-1.2.0 opencv-python-headless-5.0.0.93 pi-heif-1.4.0 pillow-avif-plugin-1.6.0 python-dotenv-1.2.3 requests_toolbelt-1.0.0 roboflow-1.4.2 shellingham-1.5.4 typer-0.25.1
#
# [notice] A new release of pip is available: 26.0.1 -> 26.2.1
# [notice] To update, run: pip install --upgrade pip

# %% [markdown]
# ## Get dataset

# %%
from roboflow import Roboflow
rf = Roboflow(api_key="3205MH29k2z3u5Ejc3HU") # THIS API KEY IS REVOKED. PLEASE USE YOUR OWN API KEY
project = rf.workspace("roboflow-jvuqo").project("football-players-detection-3zvbc")
version = project.version(1)
dataset = version.download("yolov5")

# %%
dataset.location

# %%
import shutil

shutil.move('football-players-detection-1/train',
            'football-players-detection-1/football-players-detection-1/train'
            )

shutil.move('football-players-detection-1/test',
            'football-players-detection-1/football-players-detection-1/test'
            )

shutil.move('football-players-detection-1/valid',
            'football-players-detection-1/football-players-detection-1/valid'
            )

# %% [markdown]
# ## Training

# %%
# !yolo task=detect mode=train model=yolov5x.pt data={dataset.location}/data.yaml epochs=100 imgsz=640
